# %%
# 数据一
import pandas as pd
df_mkt = pd.read_csv('mkt_price_list_all_20230705.csv')

# %%
# 数据一
import pandas as pd
df_transaction = pd.read_csv('ndm_transaction_list_all_20230705.csv')
# Out:
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_59111/1232885182.py:3: DtypeWarning: Columns (69,83,110,121,122,123,124,125,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_transaction = pd.read_csv('ndm_transaction_list_all_20230705.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件并筛选特定债券数据
ndm_transaction_data = pd.read_csv('ndm_transaction_list_all_20230705.csv')

# print(data['bond_cd'])
ndm_transaction_filtered_data = ndm_transaction_data[ndm_transaction_data['bond_cd'] == 230004]

# print(filtered_data)

# 转换时间戳格式
ndm_transaction_filtered_data['timeStamp'] = pd.to_datetime(ndm_transaction_filtered_data['dl_tm'])


# 排序
ndm_transaction_sorted_data = ndm_transaction_filtered_data.sort_values(by='timeStamp', ascending=True)

# 创建绘图
plt.figure(figsize=(14, 6))
plt.plot(ndm_transaction_sorted_data['timeStamp'], ndm_transaction_sorted_data['net_prc'], marker='o', markersize=3)
plt.xlabel('Time')
plt.ylabel('Net Price')
plt.title('Net Price of Bond 230004 Over Time | Transaction sheet')
plt.xticks(rotation=30)
plt.grid(True)

# 调整 y 轴范围
plt.ylim(min(ndm_transaction_sorted_data['net_prc']) - 0.5, max(ndm_transaction_sorted_data['net_prc']) + 1)






plt.show()
# Out:
# /Users/dennis/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3505: DtypeWarning: Columns (69,83,110,121,122,123,124,125,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_16577/2553733662.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndm_transaction_filtered_data['timeStamp'] = pd.to_datetime(ndm_transaction_filtered_data['dl_tm'])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 14
#      10 # print(filtered_data)
#      11
#      12 # 转换时间戳格式
#      13 ndm_transaction_filtered_data['timeStamp'] = pd.to_datetime(ndm_transaction_filtered_data['dl_tm'])
# ---> 14 ndm_transaction_filtered_data = ndm_transaction_filtered_data[ndm_transaction_filtered_data['dl_tm'].dt.date == pd.to_datetime('2024-10-08').date()]
#      17 # 排序
#      18 ndm_transaction_sorted_data = ndm_transaction_filtered_data.sort_values(by='timeStamp', ascending=True)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
#    5482     and name not in self._metadata
#    5483     and name not in self._accessors
#    5484     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485 ):
#    5486     return self[name]
# -> 5487 return object.__getattribute__(self, name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/accessor.py:181, in CachedAccessor.__get__(self, obj, cls)
#     178 if obj is None:
#     179     # we're accessing the attribute of the class, i.e., Dataset.geo
#     180     return self._accessor
# --> 181 accessor_obj = self._accessor(obj)
#     182 # Replace the property with the accessor object. Inspired by:
#     183 # https://www.pydanny.com/cached-property.html
#     184 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     185 # NDFrame
#     186 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/accessors.py:506, in CombinedDatetimelikeProperties.__new__(cls, data)
#     503 elif is_period_dtype(data.dtype):
#     504     return PeriodProperties(data, orig)
# --> 506 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件并筛选特定债券数据
df_mkt = pd.read_csv('mkt_price_list_all_20230705.csv')

# print(data['bond_cd'])
df_mkt_filtered_data = df_mkt[df_mkt['bond_cd'] == 230004]

# print(filtered_data)

# 转换时间戳格式
df_mkt_filtered_data['timeStamp'] = pd.to_datetime(df_mkt_filtered_data['mkt_data_upd_tm'])

# 排序
df_mkt_sorted_data = df_mkt_filtered_data.sort_values(by='timeStamp', ascending=True)

# 创建绘图
plt.figure(figsize=(14, 6))
plt.plot(df_mkt_sorted_data['timeStamp'], df_mkt_sorted_data['wghtd_avg_net_prc'], marker='o', markersize=3)
plt.plot(ndm_transaction_sorted_data['timeStamp'], ndm_transaction_sorted_data['net_prc'], marker='o', markersize=3)
plt.xlabel('Time')
plt.ylabel('wghtd_avg_net_prc')
plt.title('wghtd_avg_net_prc of Bond 230004 Over Time | Trading sheet')
plt.xticks(rotation=30)
plt.grid(True)

# 调整 y 轴范围
plt.ylim(min(df_mkt_sorted_data['wghtd_avg_net_prc']) - 2, max(df_mkt_sorted_data['wghtd_avg_net_prc']) + 0.3)

plt.show()
# Out:
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_59111/1414677581.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mkt_filtered_data['timeStamp'] = pd.to_datetime(df_mkt_filtered_data['mkt_data_upd_tm'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 读取CSV文件并筛选特定债券数据
df_mkt = pd.read_csv('mkt_price_list_all_20230705.csv')

# 筛选特定债券数据
df_mkt_filtered_data = df_mkt[df_mkt['bond_cd'] == 230004]

# 转换时间戳格式
df_mkt_filtered_data['timeStamp'] = pd.to_datetime(df_mkt_filtered_data['mkt_data_upd_tm'])

# 排序
df_mkt_sorted_data = df_mkt_filtered_data.sort_values(by='timeStamp', ascending=True)

# 创建绘图
fig, ax1 = plt.subplots(figsize=(24, 6))

# 绘制左轴数据
ax1.plot(df_mkt_sorted_data['timeStamp'], df_mkt_sorted_data['wghtd_avg_net_prc'], marker='o', markersize=3, label='wghtd_avg_net_prc')
ax1.set_xlabel('Time')
ax1.set_ylabel('wghtd_avg_net_prc')
ax1.set_title('wghtd_avg_net_prc of Bond 230004 Over Time | Trading sheet')
ax1.tick_params(axis='x', rotation=30)
# ax1.grid(True)

# 调整左轴y轴范围
y1_min = min(df_mkt_sorted_data['wghtd_avg_net_prc'])-0.1
y1_max = max(df_mkt_sorted_data['wghtd_avg_net_prc'])+0.1
ax1.set_ylim(y1_min, y1_max)

# 创建右轴

# 绘制右轴数据（假设ndm_transaction_sorted_data已经定义并且有合适的数据）
# ax2.scatter(ndm_transaction_sorted_data['timeStamp'], ndm_transaction_sorted_data['net_prc'], marker='o', color='orange')

# 读取nmnl_vol列数据
nmnl_vol = ndm_transaction_sorted_data['nmnl_vol']

# 计算合理的size范围，以及进行log转换
size_min = 10  # 最小size
size_max = 400  # 最大size
size_range = nmnl_vol  # 使用log转换

# 根据size范围进行归一化
size_scaled = (size_range - np.min(size_range)) / (np.max(size_range) - np.min(size_range))
# 映射到合理的size范围
scatter_sizes = size_min + (size_max - size_min) * size_scaled

# 创建右轴
ax2 = ax1.twinx()

# 绘制右轴数据，并传入size参数
ax2.scatter(
    ndm_transaction_sorted_data['timeStamp'],
    ndm_transaction_sorted_data['net_prc'],
    marker='o',
    color='orange',
    edgecolors='black',
    s=scatter_sizes  # 传入size参数
)


ax2.set_ylim(y1_min, y1_max)

plt.show()
# Out:
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_59111/2999411742.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mkt_filtered_data['timeStamp'] = pd.to_datetime(df_mkt_filtered_data['mkt_data_upd_tm'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ...（之前的代码）
# 读取CSV文件并筛选特定债券数据
ndm_transaction_data = pd.read_csv('ndm_transaction_list_all_20230705.csv')

# print(data['bond_cd'])
ndm_transaction_filtered_data = ndm_transaction_data[ndm_transaction_data['bond_cd'] == 230004]

# print(filtered_data)

# 转换时间戳格式
ndm_transaction_filtered_data['timeStamp'] = pd.to_datetime(ndm_transaction_filtered_data['dl_tm'])

# 排序
ndm_transaction_sorted_data = ndm_transaction_filtered_data.sort_values(by='timeStamp', ascending=True)
# 假设ndm_transaction_sorted_data已经定义并且有合适的数据

# 创建绘图
plt.figure(figsize=(10, 6))

# 绘制散点图
plt.scatter(
    ndm_transaction_sorted_data['nmnl_vol'],  # 横坐标为nmnl_vol
    ndm_transaction_sorted_data['net_prc'],   # 纵坐标为net_prc
    # s=scatter_sizes,                          # 设置散点的大小
    c='orange',                               # 散点颜色
    edgecolors='black',                       # 边框颜色
    alpha=0.7                                 # 散点的透明度
)

# 设置标题和轴标签
plt.title('Scatter Plot of nmnl_vol vs. net_prc')
plt.xlabel('nmnl_vol')
plt.ylabel('net_prc')

# 显示图表
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_59111/3213941551.py:6: DtypeWarning: Columns (69,83,110,121,122,123,124,125,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   ndm_transaction_data = pd.read_csv('ndm_transaction_list_all_20230705.csv')
# /var/folders/gj/bwfyx1ks0p17lbgn6fl1nx1c0000gp/T/ipykernel_59111/3213941551.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndm_transaction_filtered_data['timeStamp'] = pd.to_datetime(ndm_transaction_filtered_data['dl_tm'])
