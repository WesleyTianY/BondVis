# %%
[
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102544",
        "byr_instn_cn_full_nm": "河南台前农商行",
        "byr_trdr_nm": "满金平",
        "dl_tp": "0",
        "netPrice": 101.1814,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "100633.0",
        "slr_instn_cn_full_nm": "桂林银行",
        "slr_trdr_nm": "崔睿",
        "timeStamp": "2024-10-08T03:59:06.000Z",
        "transactionId": "CBT20241008301408",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.93",
        "x": 470.43305126928817,
        "y": 578.0251253439113,
        "size": "30000000.0",
        "yValue": 1.93
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "100005",
        "byr_instn_cn_full_nm": "交通银行",
        "byr_trdr_nm": "陈澳",
        "dl_tp": "0",
        "netPrice": 100.9293,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "101519.0",
        "slr_instn_cn_full_nm": "美国上海",
        "slr_trdr_nm": "张荣峰",
        "timeStamp": "2024-10-08T05:30:05.000Z",
        "transactionId": "CBT20241008301427",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.9702",
        "x": 671.1406624734151,
        "y": 522.8095625355216,
        "size": "30000000.0",
        "yValue": 1.9702
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "303319",
        "byr_instn_cn_full_nm": "山西云州农商银行",
        "byr_trdr_nm": "杨智超",
        "dl_tp": "0",
        "netPrice": 101.2128,
        "nmnl_vol": "100000000.0",
        "slr_instn_cd": "100220.0",
        "slr_instn_cn_full_nm": "华西证券",
        "slr_trdr_nm": "梅嘉恬",
        "timeStamp": "2024-10-08T05:40:17.000Z",
        "transactionId": "CBT20241008302494",
        "transactionVolume": "100000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.925",
        "x": 693.6416806190325,
        "y": 584.8927326583873,
        "size": "100000000.0",
        "yValue": 1.925
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102098",
        "byr_instn_cn_full_nm": "华福证券",
        "byr_trdr_nm": "陈云",
        "dl_tp": "0",
        "netPrice": 100.899,
        "nmnl_vol": "10000000.0",
        "slr_instn_cd": "102418.0",
        "slr_instn_cn_full_nm": "国金证券",
        "slr_trdr_nm": "黄荣超",
        "timeStamp": "2024-10-08T06:03:52.000Z",
        "transactionId": "CBT20241008303749",
        "transactionVolume": "10000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.975",
        "x": 745.6660934883932,
        "y": 516.2166595136243,
        "size": "10000000.0",
        "yValue": 1.975
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "400511",
        "byr_instn_cn_full_nm": "平安大华惠锦纯债债券基金",
        "byr_trdr_nm": "余紫楠",
        "dl_tp": "0",
        "netPrice": 100.8677,
        "nmnl_vol": "10000000.0",
        "slr_instn_cd": "102418.0",
        "slr_instn_cn_full_nm": "国金证券",
        "slr_trdr_nm": "黄荣超",
        "timeStamp": "2024-10-08T06:06:26.000Z",
        "transactionId": "CBT20241008303918",
        "transactionVolume": "10000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.98",
        "x": 751.3281143943165,
        "y": 509.3490521991481,
        "size": "10000000.0",
        "yValue": 1.98
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "101824",
        "byr_instn_cn_full_nm": "诺安联创顺鑫债券基金",
        "byr_trdr_nm": "黄怀莹",
        "dl_tp": "0",
        "netPrice": 100.8677,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "102418.0",
        "slr_instn_cn_full_nm": "国金证券",
        "slr_trdr_nm": "高翔",
        "timeStamp": "2024-10-08T06:15:03.000Z",
        "transactionId": "CBT20241008304407",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.98",
        "x": 770.3363274356307,
        "y": 509.3490521991481,
        "size": "30000000.0",
        "yValue": 1.98
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "100220",
        "byr_instn_cn_full_nm": "华西证券",
        "byr_trdr_nm": "梅嘉恬",
        "dl_tp": "0",
        "netPrice": 101.2285,
        "nmnl_vol": "100000000.0",
        "slr_instn_cd": "100047.0",
        "slr_instn_cn_full_nm": "银河证券",
        "slr_trdr_nm": "周英博",
        "timeStamp": "2024-10-08T06:16:25.000Z",
        "transactionId": "CBT20241008304492",
        "transactionVolume": "100000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.9225",
        "x": 773.3511697361871,
        "y": 588.3265363156255,
        "size": "100000000.0",
        "yValue": 1.9225
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "100021",
        "byr_instn_cn_full_nm": "北京农商银行",
        "byr_trdr_nm": "朱玉文",
        "dl_tp": "0",
        "netPrice": 101.0224,
        "nmnl_vol": "20000000.0",
        "slr_instn_cd": "101519.0",
        "slr_instn_cn_full_nm": "美国上海",
        "slr_trdr_nm": "张荣峰",
        "timeStamp": "2024-10-08T06:17:01.000Z",
        "transactionId": "CBT20241008304529",
        "transactionVolume": "20000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.9553",
        "x": 774.6747590388705,
        "y": 543.275032332661,
        "size": "20000000.0",
        "yValue": 1.9553
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "100220",
        "byr_instn_cn_full_nm": "华西证券",
        "byr_trdr_nm": "梅嘉恬",
        "dl_tp": "0",
        "netPrice": 101.2285,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "100047.0",
        "slr_instn_cn_full_nm": "银河证券",
        "slr_trdr_nm": "苏颖乔",
        "timeStamp": "2024-10-08T06:18:22.000Z",
        "transactionId": "CBT20241008304606",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.9225",
        "x": 777.6528349699081,
        "y": 588.3265363156255,
        "size": "30000000.0",
        "yValue": 1.9225
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102646",
        "byr_instn_cn_full_nm": "正阳农商行",
        "byr_trdr_nm": "张昆",
        "dl_tp": "0",
        "netPrice": 100.9303,
        "nmnl_vol": "20000000.0",
        "slr_instn_cd": "101614.0",
        "slr_instn_cn_full_nm": "鹏华中短债3个月定期开放债券基金",
        "slr_trdr_nm": "蓝天",
        "timeStamp": "2024-10-08T06:47:28.000Z",
        "transactionId": "CBT20241008306330",
        "transactionVolume": "20000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.97",
        "x": 841.846916150052,
        "y": 523.0842668281007,
        "size": "20000000.0",
        "yValue": 1.97
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102418",
        "byr_instn_cn_full_nm": "国金证券",
        "byr_trdr_nm": "马司睿",
        "dl_tp": "0",
        "netPrice": 101.3072,
        "nmnl_vol": "10000000.0",
        "slr_instn_cd": "101638.0",
        "slr_instn_cn_full_nm": "招商鑫嘉中短债债券基金",
        "slr_trdr_nm": "刘雪霏",
        "timeStamp": "2024-10-08T07:31:40.000Z",
        "transactionId": "CBT20241008309331",
        "transactionVolume": "10000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.91",
        "x": 939.3513281143943,
        "y": 605.4955546018165,
        "size": "10000000.0",
        "yValue": 1.91
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102418",
        "byr_instn_cn_full_nm": "国金证券",
        "byr_trdr_nm": "马司睿",
        "dl_tp": "0",
        "netPrice": 101.3072,
        "nmnl_vol": "10000000.0",
        "slr_instn_cd": "101638.0",
        "slr_instn_cn_full_nm": "招商稳乐中短债90天持有期债券基金",
        "slr_trdr_nm": "刘雪霏",
        "timeStamp": "2024-10-08T07:32:46.000Z",
        "transactionId": "CBT20241008309417",
        "transactionVolume": "10000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.91",
        "x": 941.7779085026472,
        "y": 605.4955546018165,
        "size": "10000000.0",
        "yValue": 1.91
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "102544",
        "byr_instn_cn_full_nm": "河南台前农商行",
        "byr_trdr_nm": "满金平",
        "dl_tp": "0",
        "netPrice": 101.2442,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "100361.0",
        "slr_instn_cn_full_nm": "长城证券",
        "slr_trdr_nm": "崔册",
        "timeStamp": "2024-10-08T07:42:06.000Z",
        "transactionId": "CBT20241008310132",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.92",
        "x": 962.3670754332775,
        "y": 591.7603399728639,
        "size": "30000000.0",
        "yValue": 1.92
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "417573",
        "byr_instn_cn_full_nm": "澳门国际银行广州分行",
        "byr_trdr_nm": "沈驰",
        "dl_tp": "0",
        "netPrice": 100.8677,
        "nmnl_vol": "30000000.0",
        "slr_instn_cd": "102418.0",
        "slr_instn_cn_full_nm": "国金证券",
        "slr_trdr_nm": "刘琛",
        "timeStamp": "2024-10-08T08:01:30.000Z",
        "transactionId": "CBT20241008311627",
        "transactionVolume": "30000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.98",
        "x": 1005.1631295533734,
        "y": 509.3490521991481,
        "size": "30000000.0",
        "yValue": 1.98
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "404280",
        "byr_instn_cn_full_nm": "泓德裕盈三个月定开债券基金",
        "byr_trdr_nm": "刘黎",
        "dl_tp": "0",
        "netPrice": 100.899,
        "nmnl_vol": "20000000.0",
        "slr_instn_cd": "102098.0",
        "slr_instn_cn_full_nm": "华福证券",
        "slr_trdr_nm": "陈云",
        "timeStamp": "2024-10-08T08:05:53.000Z",
        "transactionId": "CBT20241008312039",
        "transactionVolume": "20000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.975",
        "x": 1014.8326847368659,
        "y": 516.2166595136243,
        "size": "20000000.0",
        "yValue": 1.975
    },
    {
        "bond_cd": "240013",
        "byr_instn_cd": "400511",
        "byr_instn_cn_full_nm": "平安大华惠锦纯债债券基金",
        "byr_trdr_nm": "余紫楠",
        "dl_tp": "0",
        "netPrice": 100.899,
        "nmnl_vol": "10000000.0",
        "slr_instn_cd": "101169.0",
        "slr_instn_cn_full_nm": "山西证券",
        "slr_trdr_nm": "迟浩然",
        "timeStamp": "2024-10-08T08:35:46.000Z",
        "transactionId": "CBT20241008314483",
        "transactionVolume": "10000000.0",
        "transaction_type": "NDM",
        "yld_to_mrty": "1.975",
        "x": 1080.754785284402,
        "y": 516.2166595136243,
        "size": "10000000.0",
        "yValue": 1.975
    }
]
