# %%
import random
from faker import Faker
import json
from datetime import datetime, timedelta

# 初始化Faker库
fake = Faker('zh_CN')

# 固定的交易机构列表
institutions = [fake.company() for _ in range(10)]

# 生成单个交易
def generate_trade(trade_id, seller, buyer, start_time, price):
    volume = random.randint(1, 100)
    time_dl = start_time + timedelta(days=random.randint(0, 25), hours=random.randint(0, 23), minutes=random.randint(0, 59), seconds=random.randint(0, 59))

    return {
        "trade_id": trade_id,
        "seller": seller,
        "buyer": buyer,
        "volume": volume,
        "price": round(price, 2),
        "time_dl": time_dl.strftime("%Y-%m-%d %H:%M:%S%z")
    }

# 生成基础子序列
def generate_subsequence(base_price, length, start_id):
    subsequence = []
    price = base_price
    start_seller = random.choice(institutions) + fake.name()
    for trade_id in range(start_id, start_id + length):
        buyer = random.choice(institutions) + fake.name()
        # 10%的概率价格增加3%
        if random.random() < 0.1:
            price *= 1.03
        else:
            price += random.uniform(0.1, 2.0)
        trade = generate_trade(trade_id, start_seller, buyer, datetime.now(), price)
        subsequence.append(trade)
        start_seller = buyer  # 更新卖方
    return subsequence

# 生成模拟链路数据
def generate_mock_data(num_paths, max_trades_per_path, base_subsequences):
    mock_data = []
    next_trade_id = 1
    
    for _ in range(num_paths):
        num_trades = random.randint(5, max_trades_per_path)
        path_trades = []
        start_time = datetime(2023, 12, 1, 0, 0, 0)
        end_time = start_time + timedelta(days=25)
        profit_anomaly_score = round(random.uniform(50, 150), 2)
        institution_counts_anomaly_score = round(random.uniform(1, 5), 2)
        price_standard_deviation_anomaly_score = round(random.uniform(0, 1), 2)
        price_change_anomaly_score = round(random.uniform(0, 1), 2)

        # 随机选择几个子序列组合成完整链路
        subsequences_to_use = random.sample(base_subsequences, k=random.randint(1, min(len(base_subsequences), num_trades // 2)))
        
        # 维护链路的连续性
        if subsequences_to_use:
            # 选择第一个子序列的卖方
            first_subsequence = subsequences_to_use.pop(0)
            path_trades.extend(first_subsequence)
            next_trade_id += len(first_subsequence)

            for subseq in subsequences_to_use:
                # 确保上一个子序列的买方与当前子序列的卖方匹配
                last_buyer = path_trades[-1]['buyer']
                if subseq[0]['seller'] == last_buyer:
                    path_trades.extend(subseq)
                    next_trade_id += len(subseq)
                else:
                    # 如果不匹配，则尝试调整当前子序列
                    for i in range(len(subseq)):
                        if subseq[i]['seller'] == last_buyer:
                            path_trades.extend(subseq[i:])
                            next_trade_id += len(subseq[i:])
                            break

        # 确保链路长度符合要求
        path_trades = path_trades[:num_trades]
        
        # 确保链路首尾相接
        if path_trades and path_trades[0]['seller'] != path_trades[-1]['buyer']:
            path_trades[-1]['buyer'] = path_trades[0]['seller']
        
        mock_data.append({
            "path": f"{path_trades[0]['seller']} to {path_trades[-1]['buyer']}",
            "start_time": start_time.strftime("%Y-%m-%d %H:%M:%S"),
            "end_time": end_time.strftime("%Y-%m-%d %H:%M:%S"),
            "path_trades": path_trades,
            "profit_anomaly_score": profit_anomaly_score,
            "institution_counts_anomaly_score": institution_counts_anomaly_score,
            "price_standard_deviation_anomaly_score": price_standard_deviation_anomaly_score,
            "price_change_anomaly_score": price_change_anomaly_score
        })

    return mock_data

# 生成基础子序列
base_subsequences = []
for _ in range(20):
    start_id = len([t for sublist in base_subsequences for t in sublist]) + 1
    base_subsequences.append(generate_subsequence(100.0, random.randint(5, 10), start_id))

# 生成大量模拟数据
mock_data = generate_mock_data(num_paths=10, max_trades_per_path=8, base_subsequences=base_subsequences)

# 打印数据
print(json.dumps(mock_data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "path": "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 11,
#                 "seller": "东方峻景信息有限公司张秀英",
#                 "buyer": "精芯科技有限公司杜志强",
#                 "volume": 57,
#                 "price": 101.1,
#                 "time_dl": "2024-08-11 03:42:48"
#             },
#             {
#                 "trade_id": 12,
#                 "seller": "精芯科技有限公司杜志强",
#                 "buyer": "凌云网络有限公司向瑜",
#                 "volume": 58,
#                 "price": 102.78,
#                 "time_dl": "2024-08-14 04:16:31"
#             },
#             {
#                 "trade_id": 13,
#                 "seller": "凌云网络有限公司向瑜",
#                 "buyer": "凌云网络有限公司曹凤兰",
#                 "volume": 29,
#                 "price": 103.23,
#                 "time_dl": "2024-08-23 02:21:41"
#             },
#             {
#                 "trade_id": 14,
#                 "seller": "凌云网络有限公司曹凤兰",
#                 "buyer": "襄樊地球村网络有限公司余璐",
#                 "volume": 50,
#                 "price": 105.23,
#                 "time_dl": "2024-08-27 17:47:37"
#             },
#             {
#                 "trade_id": 15,
#                 "seller": "襄樊地球村网络有限公司余璐",
#                 "buyer": "东方峻景信息有限公司张秀英",
#                 "volume": 74,
#                 "price": 105.65,
#                 "time_dl": "2024-08-05 05:49:06"
#             }
#         ],
#         "profit_anomaly_score": 85.85,
#         "institution_counts_anomaly_score": 3.01,
#         "price_standard_deviation_anomaly_score": 0.77,
#         "price_change_anomaly_score": 0.09
#     },
#     {
#         "path": "华泰通安科技有限公司孙红 to 华泰通安科技有限公司孙红",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 128,
#                 "seller": "华泰通安科技有限公司孙红",
#                 "buyer": "惠派国际公司网络有限公司周凤兰",
#                 "volume": 34,
#                 "price": 101.27,
#                 "time_dl": "2024-08-26 09:49:48"
#             },
#             {
#                 "trade_id": 129,
#                 "seller": "惠派国际公司网络有限公司周凤兰",
#                 "buyer": "晖来计算机网络有限公司陈辉",
#                 "volume": 63,
#                 "price": 102.04,
#                 "time_dl": "2024-08-26 23:05:45"
#             },
#             {
#                 "trade_id": 130,
#                 "seller": "晖来计算机网络有限公司陈辉",
#                 "buyer": "维旺明科技有限公司黄俊",
#                 "volume": 19,
#                 "price": 102.44,
#                 "time_dl": "2024-08-09 14:05:29"
#             },
#             {
#                 "trade_id": 131,
#                 "seller": "维旺明科技有限公司黄俊",
#                 "buyer": "惠派国际公司网络有限公司金娟",
#                 "volume": 11,
#                 "price": 103.19,
#                 "time_dl": "2024-08-13 18:32:18"
#             },
#             {
#                 "trade_id": 132,
#                 "seller": "惠派国际公司网络有限公司金娟",
#                 "buyer": "东方峻景信息有限公司易琳",
#                 "volume": 27,
#                 "price": 105.04,
#                 "time_dl": "2024-08-21 00:25:09"
#             },
#             {
#                 "trade_id": 133,
#                 "seller": "东方峻景信息有限公司易琳",
#                 "buyer": "晖来计算机网络有限公司谢红",
#                 "volume": 30,
#                 "price": 105.43,
#                 "time_dl": "2024-08-05 08:28:04"
#             },
#             {
#                 "trade_id": 134,
#                 "seller": "晖来计算机网络有限公司谢红",
#                 "buyer": "华泰通安科技有限公司孙红",
#                 "volume": 8,
#                 "price": 107.22,
#                 "time_dl": "2024-08-14 22:40:07"
#             }
#         ],
#         "profit_anomaly_score": 96.92,
#         "institution_counts_anomaly_score": 1.55,
#         "price_standard_deviation_anomaly_score": 0.38,
#         "price_change_anomaly_score": 0.9
#     },
#     {
#         "path": "群英传媒有限公司黎杨 to 群英传媒有限公司黎杨",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 21,
#                 "seller": "群英传媒有限公司黎杨",
#                 "buyer": "维旺明科技有限公司刘明",
#                 "volume": 60,
#                 "price": 101.82,
#                 "time_dl": "2024-08-07 11:12:09"
#             },
#             {
#                 "trade_id": 22,
#                 "seller": "维旺明科技有限公司刘明",
#                 "buyer": "浙大万朋科技有限公司马兵",
#                 "volume": 26,
#                 "price": 104.87,
#                 "time_dl": "2024-08-04 03:46:02"
#             },
#             {
#                 "trade_id": 23,
#                 "seller": "浙大万朋科技有限公司马兵",
#                 "buyer": "浙大万朋科技有限公司赵丽丽",
#                 "volume": 69,
#                 "price": 105.06,
#                 "time_dl": "2024-08-05 09:41:52"
#             },
#             {
#                 "trade_id": 24,
#                 "seller": "浙大万朋科技有限公司赵丽丽",
#                 "buyer": "浙大万朋科技有限公司柴涛",
#                 "volume": 52,
#                 "price": 106.9,
#                 "time_dl": "2024-08-05 08:37:50"
#             },
#             {
#                 "trade_id": 25,
#                 "seller": "浙大万朋科技有限公司柴涛",
#                 "buyer": "群英传媒有限公司黎杨",
#                 "volume": 51,
#                 "price": 108.64,
#                 "time_dl": "2024-08-14 21:55:20"
#             }
#         ],
#         "profit_anomaly_score": 89.15,
#         "institution_counts_anomaly_score": 3.34,
#         "price_standard_deviation_anomaly_score": 0.07,
#         "price_change_anomaly_score": 0.88
#     },
#     {
#         "path": "惠派国际公司网络有限公司梁秀英 to 惠派国际公司网络有限公司梁秀英",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 88,
#                 "seller": "惠派国际公司网络有限公司梁秀英",
#                 "buyer": "凌云网络有限公司胡金凤",
#                 "volume": 57,
#                 "price": 100.71,
#                 "time_dl": "2024-08-05 03:13:35"
#             },
#             {
#                 "trade_id": 89,
#                 "seller": "凌云网络有限公司胡金凤",
#                 "buyer": "襄樊地球村网络有限公司陈娜",
#                 "volume": 96,
#                 "price": 101.35,
#                 "time_dl": "2024-08-08 21:37:21"
#             },
#             {
#                 "trade_id": 90,
#                 "seller": "襄樊地球村网络有限公司陈娜",
#                 "buyer": "惠派国际公司网络有限公司范玉兰",
#                 "volume": 81,
#                 "price": 101.72,
#                 "time_dl": "2024-08-12 12:07:02"
#             },
#             {
#                 "trade_id": 91,
#                 "seller": "惠派国际公司网络有限公司范玉兰",
#                 "buyer": "维旺明科技有限公司曹荣",
#                 "volume": 13,
#                 "price": 102.57,
#                 "time_dl": "2024-08-06 06:07:23"
#             },
#             {
#                 "trade_id": 92,
#                 "seller": "维旺明科技有限公司曹荣",
#                 "buyer": "晖来计算机网络有限公司黄建",
#                 "volume": 16,
#                 "price": 103.52,
#                 "time_dl": "2024-08-06 06:54:54"
#             },
#             {
#                 "trade_id": 93,
#                 "seller": "晖来计算机网络有限公司黄建",
#                 "buyer": "惠派国际公司网络有限公司梁秀英",
#                 "volume": 94,
#                 "price": 105.04,
#                 "time_dl": "2024-08-09 07:33:51"
#             }
#         ],
#         "profit_anomaly_score": 96.72,
#         "institution_counts_anomaly_score": 2.03,
#         "price_standard_deviation_anomaly_score": 0.1,
#         "price_change_anomaly_score": 0.49
#     },
#     {
#         "path": "浙大万朋科技有限公司王丽华 to 浙大万朋科技有限公司王丽华",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 58,
#                 "seller": "浙大万朋科技有限公司王丽华",
#                 "buyer": "浙大万朋科技有限公司白洁",
#                 "volume": 89,
#                 "price": 101.65,
#                 "time_dl": "2024-08-12 11:52:00"
#             },
#             {
#                 "trade_id": 59,
#                 "seller": "浙大万朋科技有限公司白洁",
#                 "buyer": "晖来计算机网络有限公司杨建军",
#                 "volume": 73,
#                 "price": 101.76,
#                 "time_dl": "2024-08-11 10:15:03"
#             },
#             {
#                 "trade_id": 60,
#                 "seller": "晖来计算机网络有限公司杨建军",
#                 "buyer": "晖来计算机网络有限公司庄倩",
#                 "volume": 28,
#                 "price": 103.54,
#                 "time_dl": "2024-08-17 20:38:56"
#             },
#             {
#                 "trade_id": 61,
#                 "seller": "晖来计算机网络有限公司庄倩",
#                 "buyer": "晖来计算机网络有限公司方明",
#                 "volume": 48,
#                 "price": 106.64,
#                 "time_dl": "2024-08-15 01:57:37"
#             },
#             {
#                 "trade_id": 62,
#                 "seller": "晖来计算机网络有限公司方明",
#                 "buyer": "精芯科技有限公司赵凯",
#                 "volume": 83,
#                 "price": 106.82,
#                 "time_dl": "2024-08-14 15:18:20"
#             },
#             {
#                 "trade_id": 63,
#                 "seller": "精芯科技有限公司赵凯",
#                 "buyer": "华泰通安科技有限公司吴秀兰",
#                 "volume": 65,
#                 "price": 107.19,
#                 "time_dl": "2024-08-11 22:10:49"
#             },
#             {
#                 "trade_id": 64,
#                 "seller": "华泰通安科技有限公司吴秀兰",
#                 "buyer": "浙大万朋科技有限公司王丽华",
#                 "volume": 5,
#                 "price": 108.93,
#                 "time_dl": "2024-08-08 20:51:13"
#             }
#         ],
#         "profit_anomaly_score": 69.85,
#         "institution_counts_anomaly_score": 4.08,
#         "price_standard_deviation_anomaly_score": 0.95,
#         "price_change_anomaly_score": 0.75
#     },
#     {
#         "path": "维旺明科技有限公司马金凤 to 维旺明科技有限公司马金凤",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 136,
#                 "seller": "维旺明科技有限公司马金凤",
#                 "buyer": "维旺明科技有限公司石慧",
#                 "volume": 78,
#                 "price": 100.66,
#                 "time_dl": "2024-08-19 05:13:14"
#             },
#             {
#                 "trade_id": 137,
#                 "seller": "维旺明科技有限公司石慧",
#                 "buyer": "群英传媒有限公司黄红梅",
#                 "volume": 58,
#                 "price": 100.83,
#                 "time_dl": "2024-08-22 03:54:59"
#             },
#             {
#                 "trade_id": 138,
#                 "seller": "群英传媒有限公司黄红梅",
#                 "buyer": "晖来计算机网络有限公司苏敏",
#                 "volume": 77,
#                 "price": 103.85,
#                 "time_dl": "2024-08-21 05:22:31"
#             },
#             {
#                 "trade_id": 139,
#                 "seller": "晖来计算机网络有限公司苏敏",
#                 "buyer": "群英传媒有限公司杨淑英",
#                 "volume": 87,
#                 "price": 105.32,
#                 "time_dl": "2024-08-05 06:04:18"
#             },
#             {
#                 "trade_id": 140,
#                 "seller": "群英传媒有限公司杨淑英",
#                 "buyer": "维旺明科技有限公司马金凤",
#                 "volume": 57,
#                 "price": 106.97,
#                 "time_dl": "2024-08-20 15:58:20"
#             }
#         ],
#         "profit_anomaly_score": 54.57,
#         "institution_counts_anomaly_score": 4.78,
#         "price_standard_deviation_anomaly_score": 0.3,
#         "price_change_anomaly_score": 0.63
#     },
#     {
#         "path": "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 11,
#                 "seller": "东方峻景信息有限公司张秀英",
#                 "buyer": "精芯科技有限公司杜志强",
#                 "volume": 57,
#                 "price": 101.1,
#                 "time_dl": "2024-08-11 03:42:48"
#             },
#             {
#                 "trade_id": 12,
#                 "seller": "精芯科技有限公司杜志强",
#                 "buyer": "凌云网络有限公司向瑜",
#                 "volume": 58,
#                 "price": 102.78,
#                 "time_dl": "2024-08-14 04:16:31"
#             },
#             {
#                 "trade_id": 13,
#                 "seller": "凌云网络有限公司向瑜",
#                 "buyer": "凌云网络有限公司曹凤兰",
#                 "volume": 29,
#                 "price": 103.23,
#                 "time_dl": "2024-08-23 02:21:41"
#             },
#             {
#                 "trade_id": 14,
#                 "seller": "凌云网络有限公司曹凤兰",
#                 "buyer": "襄樊地球村网络有限公司余璐",
#                 "volume": 50,
#                 "price": 105.23,
#                 "time_dl": "2024-08-27 17:47:37"
#             },
#             {
#                 "trade_id": 15,
#                 "seller": "襄樊地球村网络有限公司余璐",
#                 "buyer": "东方峻景信息有限公司张秀英",
#                 "volume": 74,
#                 "price": 105.65,
#                 "time_dl": "2024-08-05 05:49:06"
#             },
#             {
#                 "trade_id": 16,
#                 "seller": "维旺明科技有限公司李静",
#                 "buyer": "华泰通安科技有限公司刘玲",
#                 "volume": 56,
#                 "price": 107.52,
#                 "time_dl": "2024-08-25 09:19:23"
#             },
#             {
#                 "trade_id": 17,
#                 "seller": "华泰通安科技有限公司刘玲",
#                 "buyer": "东方峻景信息有限公司张秀英",
#                 "volume": 50,
#                 "price": 107.99,
#                 "time_dl": "2024-08-11 07:28:32"
#             }
#         ],
#         "profit_anomaly_score": 105.9,
#         "institution_counts_anomaly_score": 3.11,
#         "price_standard_deviation_anomaly_score": 0.8,
#         "price_change_anomaly_score": 0.72
#     },
#     {
#         "path": "浙大万朋科技有限公司陈兵 to 浙大万朋科技有限公司陈兵",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 106,
#                 "seller": "浙大万朋科技有限公司陈兵",
#                 "buyer": "华泰通安科技有限公司崔琳",
#                 "volume": 89,
#                 "price": 100.79,
#                 "time_dl": "2024-08-12 02:07:48"
#             },
#             {
#                 "trade_id": 107,
#                 "seller": "华泰通安科技有限公司崔琳",
#                 "buyer": "华泰通安科技有限公司杨玉英",
#                 "volume": 82,
#                 "price": 101.44,
#                 "time_dl": "2024-08-21 10:59:29"
#             },
#             {
#                 "trade_id": 108,
#                 "seller": "华泰通安科技有限公司杨玉英",
#                 "buyer": "惠派国际公司网络有限公司陈燕",
#                 "volume": 60,
#                 "price": 103.41,
#                 "time_dl": "2024-08-17 15:58:03"
#             },
#             {
#                 "trade_id": 109,
#                 "seller": "惠派国际公司网络有限公司陈燕",
#                 "buyer": "维旺明科技有限公司李荣",
#                 "volume": 89,
#                 "price": 105.22,
#                 "time_dl": "2024-08-24 11:41:03"
#             },
#             {
#                 "trade_id": 110,
#                 "seller": "维旺明科技有限公司李荣",
#                 "buyer": "东方峻景信息有限公司汪帅",
#                 "volume": 5,
#                 "price": 105.86,
#                 "time_dl": "2024-08-17 22:25:52"
#             },
#             {
#                 "trade_id": 111,
#                 "seller": "东方峻景信息有限公司汪帅",
#                 "buyer": "惠派国际公司网络有限公司汪建华",
#                 "volume": 7,
#                 "price": 106.26,
#                 "time_dl": "2024-08-07 15:05:22"
#             },
#             {
#                 "trade_id": 112,
#                 "seller": "惠派国际公司网络有限公司汪建华",
#                 "buyer": "浙大万朋科技有限公司陈兵",
#                 "volume": 8,
#                 "price": 106.9,
#                 "time_dl": "2024-08-07 12:45:04"
#             }
#         ],
#         "profit_anomaly_score": 87.23,
#         "institution_counts_anomaly_score": 3.17,
#         "price_standard_deviation_anomaly_score": 0.45,
#         "price_change_anomaly_score": 0.29
#     },
#     {
#         "path": "维旺明科技有限公司张凤英 to 维旺明科技有限公司张凤英",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 115,
#                 "seller": "维旺明科技有限公司张凤英",
#                 "buyer": "惠派国际公司网络有限公司陈洁",
#                 "volume": 93,
#                 "price": 100.49,
#                 "time_dl": "2024-08-03 16:04:04"
#             },
#             {
#                 "trade_id": 116,
#                 "seller": "惠派国际公司网络有限公司陈洁",
#                 "buyer": "浙大万朋科技有限公司穆淑英",
#                 "volume": 6,
#                 "price": 100.88,
#                 "time_dl": "2024-08-18 03:11:38"
#             },
#             {
#                 "trade_id": 117,
#                 "seller": "浙大万朋科技有限公司穆淑英",
#                 "buyer": "浙大万朋科技有限公司许艳",
#                 "volume": 1,
#                 "price": 101.54,
#                 "time_dl": "2024-08-11 11:48:47"
#             },
#             {
#                 "trade_id": 118,
#                 "seller": "浙大万朋科技有限公司许艳",
#                 "buyer": "华泰通安科技有限公司石玉兰",
#                 "volume": 57,
#                 "price": 102.55,
#                 "time_dl": "2024-08-22 06:16:50"
#             },
#             {
#                 "trade_id": 119,
#                 "seller": "华泰通安科技有限公司石玉兰",
#                 "buyer": "维旺明科技有限公司张凤英",
#                 "volume": 71,
#                 "price": 104.08,
#                 "time_dl": "2024-08-17 06:22:56"
#             }
#         ],
#         "profit_anomaly_score": 112.48,
#         "institution_counts_anomaly_score": 2.48,
#         "price_standard_deviation_anomaly_score": 0.11,
#         "price_change_anomaly_score": 0.94
#     },
#     {
#         "path": "晖来计算机网络有限公司张小红 to 晖来计算机网络有限公司张小红",
#         "start_time": "2023-12-01 00:00:00",
#         "end_time": "2023-12-26 00:00:00",
#         "path_trades": [
#             {
#                 "trade_id": 31,
#                 "seller": "晖来计算机网络有限公司张小红",
#                 "buyer": "晖来计算机网络有限公司涂丽娟",
#                 "volume": 14,
#                 "price": 101.72,
#                 "time_dl": "2024-08-27 20:13:26"
#             },
#             {
#                 "trade_id": 32,
#                 "seller": "晖来计算机网络有限公司涂丽娟",
#                 "buyer": "东方峻景信息有限公司王玉华",
#                 "volume": 57,
#                 "price": 101.89,
#                 "time_dl": "2024-08-09 07:43:17"
#             },
#             {
#                 "trade_id": 33,
#                 "seller": "东方峻景信息有限公司王玉华",
#                 "buyer": "凌云网络有限公司伍娜",
#                 "volume": 46,
#                 "price": 102.21,
#                 "time_dl": "2024-08-14 16:31:20"
#             },
#             {
#                 "trade_id": 34,
#                 "seller": "凌云网络有限公司伍娜",
#                 "buyer": "东方峻景信息有限公司胡丹丹",
#                 "volume": 50,
#                 "price": 103.39,
#                 "time_dl": "2024-08-10 23:45:18"
#             },
#             {
#                 "trade_id": 35,
#                 "seller": "东方峻景信息有限公司胡丹丹",
#                 "buyer": "晖来计算机网络有限公司张小红",
#                 "volume": 52,
#                 "price": 104.74,
#                 "time_dl": "2024-08-07 19:46:59"
#             }
#         ],
#         "profit_anomaly_score": 117.26,
#         "institution_counts_anomaly_score": 2.12,
#         "price_standard_deviation_anomaly_score": 0.45,
#         "price_change_anomaly_score": 0.75
#     }
# ]

# %%
import json
from collections import defaultdict

# 假设 mock_data 是之前生成的链路数据
mock_data = mock_data

# 提取子序列
def extract_subsequences(path_trades):
    subsequences = []
    for i in range(len(path_trades)):
        for j in range(i + 1, len(path_trades) + 1):
            subsequence = path_trades[i:j]
            if len(subsequence) > 1:
                subsequences.append(tuple((t['seller'], t['buyer']) for t in subsequence))
    return subsequences

# 标识公共子序列并进行合并
def merge_common_subsequences(data):
    subsequence_map = defaultdict(list)
    
    for item in data:
        path_trades = item['path_trades']
        subsequences = extract_subsequences(path_trades)
        for subseq in subsequences:
            subsequence_map[subseq].append(item)
    
    # 创建一个映射表，将公共子序列映射到其所在的链路
    merged_subsequences = defaultdict(list)
    for subseq, paths in subsequence_map.items():
        if len(paths) > 1:
            merged_subsequences[subseq] = list(set(path['path'] for path in paths))
    
    return merged_subsequences

# 将合并后的数据转换为结构化数据
def convert_to_structured_data(merged_subsequences):
    structured_data = []
    
    for subseq, paths in merged_subsequences.items():
        structured_data.append({
            "subsequence": subseq,
            "paths": paths
        })
    
    return structured_data

# 合并公共子序列并生成结构化数据
merged_subsequences = merge_common_subsequences(mock_data)
structured_data = convert_to_structured_data(merged_subsequences)

# 打印结构化数据
print(json.dumps(structured_data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "subsequence": [
#             [
#                 "东方峻景信息有限公司张秀英",
#                 "精芯科技有限公司杜志强"
#             ],
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "东方峻景信息有限公司张秀英",
#                 "精芯科技有限公司杜志强"
#             ],
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "东方峻景信息有限公司张秀英",
#                 "精芯科技有限公司杜志强"
#             ],
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "东方峻景信息有限公司张秀英",
#                 "精芯科技有限公司杜志强"
#             ],
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ],
#             [
#                 "襄樊地球村网络有限公司余璐",
#                 "东方峻景信息有限公司张秀英"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "精芯科技有限公司杜志强",
#                 "凌云网络有限公司向瑜"
#             ],
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ],
#             [
#                 "襄樊地球村网络有限公司余璐",
#                 "东方峻景信息有限公司张秀英"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "凌云网络有限公司向瑜",
#                 "凌云网络有限公司曹凤兰"
#             ],
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ],
#             [
#                 "襄樊地球村网络有限公司余璐",
#                 "东方峻景信息有限公司张秀英"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     },
#     {
#         "subsequence": [
#             [
#                 "凌云网络有限公司曹凤兰",
#                 "襄樊地球村网络有限公司余璐"
#             ],
#             [
#                 "襄樊地球村网络有限公司余璐",
#                 "东方峻景信息有限公司张秀英"
#             ]
#         ],
#         "paths": [
#             "东方峻景信息有限公司张秀英 to 东方峻景信息有限公司张秀英"
#         ]
#     }
# ]
